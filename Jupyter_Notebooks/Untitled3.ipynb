# %%
# !pip install unfolded.map-sdk
# Out:
# ...
#   Obtaining dependency information for unfolded.map-sdk from https://files.pythonhosted.org/packages/77/00/005694d5fe796463b560c5c2862ed54a58f3164737c467091cd7a4533e7a/unfolded.map_sdk-1.13.0-py2.py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/138.6 kB ? eta -:--:--
#      -------------------------------------- 138.6/138.6 kB 8.6 MB/s eta 0:00:00
# ...
#   Obtaining dependency information for pydantic<2.0,>=1.9 from https://files.pythonhosted.org/packages/9c/2b/20029a5c58943c0dd19bbf1fda77e820101b63a26237b060217821a3daa3/pydantic-1.10.13-cp311-cp311-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/150.9 kB ? eta -:--:--
#      -------------------------------------- 150.9/150.9 kB 9.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/245.7 kB ? eta -:--:--
#      -------------------------------------- 245.7/245.7 kB 7.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/8.5 MB ? eta -:--:--
# ...

# %%
{
  "version": "v1",
  "config": {
    "visState": {
      "filters": [],
      "layers": [
        {
          "id": "20w48an",
          "type": "trip",
          "config": {
            "dataId": "c6752645-088c-4ded-84c9-c48d9b634791",
            "label": "new layer",
            "color": [
              221,
              178,
              124
            ],
            "isVisible": true,
            "hidden": false,
            "visConfig": {
              "opacity": 0.8,
              "thickness": 0.2,
              "colorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#4C0035",
                  "#5B0036",
                  "#6B0036",
                  "#7B0034",
                  "#8B002F",
                  "#9B0027",
                  "#A8141C",
                  "#B12616",
                  "#BB3415",
                  "#C34212",
                  "#CB4F0F",
                  "#D35C0C",
                  "#DB6807",
                  "#E17502",
                  "#E88200",
                  "#ED8F00",
                  "#F39C00",
                  "#F7A900",
                  "#FBB600",
                  "#FFC300"
                ]
              },
              "trailLength": 1000,
              "fadeTrail": false,
              "billboard": false,
              "sizeRange": [
                0,
                10
              ],
              "sizeScale": 5.8,
              "scenegraph": "boeing777",
              "scenegraphEnabled": true,
              "scenegraphColorEnabled": true,
              "scenegraphUseTrailColor": false,
              "scenegraphColor": null,
              "scenegraphCustomModelUrl": "",
              "adjustRoll": 0,
              "adjustPitch": 0,
              "adjustYaw": 180,
              "invertRoll": false,
              "invertPitch": false,
              "invertYaw": false,
              "fixedRoll": true,
              "fixedPitch": true,
              "fixedYaw": true
            },
            "textLabel": [
              {
                "size": 14,
                "color": [
                  255,
                  255,
                  255
                ],
                "field": [
                  {
                    "field": {
                      "name": "id_vuelo",
                      "type": "string"
                    },
                    "format": ""
                  }
                ],
                "offset": [
                  0,
                  0
                ],
                "anchor": "start",
                "alignment": "center",
                "background": false,
                "backgroundColor": null,
                "outlineColor": [
                  255,
                  0,
                  0,
                  255
                ],
                "outlineWidth": 0
              }
            ],
            "columnMode": "table",
            "columns": {
              "id": "id_vuelo",
              "lat": "latitud_aeropuerto",
              "lng": "longitud_aeropuerto",
              "timestamp": "hora"
            }
          },
          "visualChannels": {
            "colorField": {
              "type": "string",
              "name": "id_vuelo"
            },
            "colorScale": "ordinal",
            "sizeField": null,
            "sizeScale": "linear",
            "rollField": null,
            "rollScale": "linear",
            "pitchField": null,
            "pitchScale": "linear",
            "yawField": null,
            "yawScale": "linear"
          }
        }
      ],
      "effects": [],
      "interactionConfig": {
        "tooltip": {
          "fieldsToShow": {
            "c6752645-088c-4ded-84c9-c48d9b634791": [
              {
                "name": "id_vuelo",
                "format": null
              },
              {
                "name": "latitud_aeropuerto",
                "format": null
              },
              {
                "name": "longitud_aeropuerto",
                "format": null
              },
              {
                "name": "hora",
                "format": null
              }
            ]
          },
          "compareMode": false,
          "compareType": "absolute",
          "enabled": true
        },
        "brush": {
          "size": 0.1,
          "enabled": false
        },
        "geocoder": {
          "enabled": false
        },
        "coordinate": {
          "enabled": false
        },
        "annotation": {
          "enabled": true
        }
      },
      "layerBlending": "normal",
      "overlayBlending": "normal",
      "splitMaps": [],
      "animationConfig": {
        "currentTime": 1698829319525.65,
        "speed": 0.341
      },
      "editor": {
        "features": [],
        "visible": true
      },
      "metrics": [],
      "geoKeys": [],
      "groupBys": [],
      "datasets": {
        "fieldDisplayNames": {
          "c6752645-088c-4ded-84c9-c48d9b634791": {}
        },
        "fieldDisplayFormats": {
          "c6752645-088c-4ded-84c9-c48d9b634791": {}
        },
        "datasetColors": {
          "c6752645-088c-4ded-84c9-c48d9b634791": [
            143,
            47,
            191
          ]
        }
      },
      "joins": [],
      "analyses": [],
      "charts": [
        {
          "id": "3078h79",
          "title": "Count of rows in flights4.csv",
          "dataId": "c6752645-088c-4ded-84c9-c48d9b634791",
          "applyFilters": true,
          "type": "bigNumber",
          "axis": {
            "field": null,
            "aggregation": "COUNT",
            "title": null
          },
          "chartDisplay": {
            "showTotal": true,
            "format": "DECIMAL_SHORT_COMMA"
          },
          "useMetric": false
        }
      ],
      "annotations": [],
      "layerOrder": [
        "20w48an"
      ],
      "projectColors": [
        "#000000",
        "#F7F8FA"
      ]
    },
    "mapState": {
      "bearing": 0,
      "dragRotate": false,
      "latitude": -3.0966151703339166,
      "longitude": 21.1940107107821,
      "pitch": 0,
      "zoom": 0.6850500289971815,
      "isSplit": false,
      "isViewportSynced": true,
      "isZoomLocked": false,
      "splitMapViewports": [],
      "mapViewMode": "MODE_2D",
      "mapSplitMode": "SINGLE_MAP",
      "globe": {
        "enabled": false,
        "config": {
          "atmosphere": true,
          "azimuth": false,
          "azimuthAngle": 45,
          "terminator": true,
          "terminatorOpacity": 0.35,
          "basemap": true,
          "labels": false,
          "labelsColor": [
            114.75,
            114.75,
            114.75
          ],
          "adminLines": true,
          "adminLinesColor": [
            40,
            63,
            93
          ],
          "water": true,
          "waterColor": [
            17,
            35,
            48
          ],
          "surface": true,
          "surfaceColor": [
            9,
            16,
            29
          ]
        }
      }
    },
    "mapStyle": {
      "styleType": "dark",
      "topLayerGroups": {},
      "visibleLayerGroups": {
        "label": true,
        "road": true,
        "border": false,
        "building": true,
        "water": true,
        "land": true,
        "3d building": false
      },
      "threeDBuildingColor": [
        9.665468314072012,
        17.18305478057247,
        31.1442867897876
      ],
      "backgroundColor": [
        255,
        255,
        255
      ],
      "mapStyles": {}
    },
    "uiState": {}
  }
}
