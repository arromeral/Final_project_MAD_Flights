# %% [markdown]
# # CRUCE DE LAS TRES TABLAS OBTENIDAS Y LIMPIADAS

# %% [markdown]
# ## En este Notebook se va a desarrollar el proceso para identificar cada registro de vuelo con el registro de información de tráfico aereo del día correspondiente y con el parte METAR anterior a la hora programada de salida de cada vuelo.

# %% [markdown]
# Para ello, debido al gran número de registros que se van a "cruzar" entre los diferentes DataFrames, se va a utilizar la librería <span style="color:red">**DASK**</span> por su mejor eficiencia y velocidad respecto a Pandas.

# %%
# %pip install "dask[complete]"
# %pip install dask_ml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# ...

# %%
import time
import numpy as np
import pandas as pd
import dask
import dask.dataframe as dd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Se cargan en DataFrame de *Dask* los 3 datasets previamente limpiados

# %%
fl_dask = dd.read_csv("../data/flights/flights_total.csv",dtype={"arr_mins_of_delay": "object", "dep_mins_of_delay": "object"})
mt_dask = dd.read_csv("../data/metars/metars_2017_2023.csv")
# mad_dask = dd.read_csv("../data/eurocontrol_MAD_data/MAD_data.csv")

# %%
fl_dask.head()
# Out:
#    flight_id  departure_date_time cod_flight_IATA cod_flight_ICAO         day  \
# 0          1  2023-10-31 23:59:00          IB6833         IBE6833  2023-10-31
# 1          2  2023-10-31 23:59:00          IB6841         IBE6841  2023-10-31
# 2          3  2023-10-31 23:59:00          IB6011         IBE6011  2023-10-31
# 3          4  2023-10-31 23:55:00          IB6589         IBE6589  2023-10-31
# 4          5  2023-10-31 23:55:00          IB6409         IBE6409  2023-10-31
#
#   week_day  status airliner cod_airliner_IATA cod_airliner_ICAO  ...  \
# 0  Tuesday  Landed   Iberia                IB               IBE  ...
# 1  Tuesday  Landed   Iberia                IB               IBE  ...
# 2  Tuesday  Landed   Iberia                IB               IBE  ...
# 3  Tuesday  Landed   Iberia                IB               IBE  ...
# 4  Tuesday  Landed   Iberia                IB               IBE  ...
#
#   dep_situation dep_mins_of_delay          city cod_airport_IATA  \
# ...

# %%
mt_dask.head()
# Out:
#    Metar_id            Date_time         Day   Hour Condition  Temperature  \
# 0         1  2023-10-31 23:30:00  2023-10-31  23:30      Fair            8
# 1         2  2023-10-31 23:00:00  2023-10-31  23:00      Fair            8
# 2         3  2023-10-31 22:30:00  2023-10-31  22:30      Fair            8
# 3         4  2023-10-31 22:00:00  2023-10-31  22:00     Clear            8
# 4         5  2023-10-31 21:30:00  2023-10-31  21:30     Clear            8
#
#    Wind  Gusts  Relative_hum  Pressure
# 0     3      0            93    1017.0
# 1     1      0            87    1017.0
# 2     0      0            93    1017.0
# 3     0      0            93    1017.0
# 4     0      0            93    1017.0

# %% [markdown]
# ## Se homogeniza el nombre de las columnas por las que se van a cruzar los registros, se ponen en un formato *datetime* común y se ordenan.

# %%
fl_dask = fl_dask.rename(columns={'departure_date_time': 'Date_time'})

# %%
mt_dask['Date_time'] = dd.to_datetime(mt_dask['Date_time'])
fl_dask['Date_time'] = dd.to_datetime(fl_dask['Date_time'])

# %%
fl_dask = fl_dask.sort_values('Date_time')
mt_dask = mt_dask.sort_values('Date_time')

# %% [markdown]
# ## Se realiza un merge entre los dataframes de vuelos y metars por el Date_time, cogiendo el metar justamente anterior

# %%
# %%time
fl_dask = fl_dask.sort_values('Date_time')
mtr_dask = mt_dask.sort_values('Date_time')

# Realiza el merge asof para encontrar el parte meteorológico más cercano en el tiempo
fl_dask = dd.merge_asof(fl_dask, mt_dask, on='Date_time', direction='backward')
# Out:
# CPU times: total: 1min 41s
# Wall time: 2min 39s

# %%
pd.set_option('display.max_columns', None)

# %%
fl_dask.head()
# Out:
#             Date_time  flight_id cod_flight_IATA cod_flight_ICAO         day  \
# 0 2017-11-01 00:05:00     922599          TP1005         TAP1005  2017-11-01
# 1 2017-11-01 00:10:00     922598          IB3118         IBE3118  2017-11-01
# 2 2017-11-01 00:13:00     922597          FX5036         FDX5036  2017-11-01
# 3 2017-11-01 00:40:00     922596          IB6409         IBE6409  2017-11-01
# 4 2017-11-01 00:40:00     922595          IB6841         IBE6841  2017-11-01
#
#     week_day  status                 airliner cod_airliner_IATA  \
# 0  Wednesday  Landed       TAP - Air Portugal                TP
# 1  Wednesday  Landed                   Iberia                IB
# 2  Wednesday  Landed  Federal Express (FedEx)                FX
# 3  Wednesday  Landed                   Iberia                IB
# 4  Wednesday  Landed                   Iberia                IB
#
#   cod_airliner_ICAO Scheduled_dep depart_time dep_situation dep_mins_of_delay  \
# ...

# %%
fl_dask = fl_dask.sort_values('Date_time', ascending=False)
fl_dask.head()
# Out:
#                  Date_time  flight_id cod_flight_IATA cod_flight_ICAO  \
# 497985 2023-10-31 23:59:00          1          IB6833         IBE6833
# 497984 2023-10-31 23:59:00          3          IB6011         IBE6011
# 497983 2023-10-31 23:59:00          2          IB6841         IBE6841
# 497982 2023-10-31 23:55:00          6          IB6827         IBE6827
# 497981 2023-10-31 23:55:00          4          IB6589         IBE6589
#
#                day week_day  status airliner cod_airliner_IATA  \
# 497985  2023-10-31  Tuesday  Landed   Iberia                IB
# 497984  2023-10-31  Tuesday  Landed   Iberia                IB
# 497983  2023-10-31  Tuesday  Landed   Iberia                IB
# 497982  2023-10-31  Tuesday  Landed   Iberia                IB
# 497981  2023-10-31  Tuesday  Landed   Iberia                IB
#
#        cod_airliner_ICAO Scheduled_dep depart_time dep_situation  \
# 497985               IBE         23:59       00:34          late
# ...

# %%
fl_dask = fl_dask.rename(columns={'day': 'Date'})

# %%
fl_dask.info()
# Out:
# <class 'dask.dataframe.core.DataFrame'>
# Columns: 31 entries, Date_time to Pressure
# dtypes: datetime64[ns](1), object(22), float64(1), int64(7)

# %%
forma_df = fl_dask.shape[0].compute(), fl_dask.shape[1]
print("Forma del DataFrame:", forma_df)
# Out:
# Forma del DataFrame: (922599, 31)

# %%
fl_dask.to_csv("../data/flights/flights_with_metars.csv", index = False)
# Out:
# ['C:\\Users\\daarr\\Desktop\\Ironhack\\Proyectos\\Final_project_MAD_Flights\\data\\flights\\flights_with_metars.csv\\0.part',
#  'C:\\Users\\daarr\\Desktop\\Ironhack\\Proyectos\\Final_project_MAD_Flights\\data\\flights\\flights_with_metars.csv\\1.part']

# %%
fl_dask.to_parquet("../data/flights/flights_with_metars.gz", compression='gzip', write_index=False)

# %%
fl_dask.to_json("../data/flights/flights_with_metars.json")
# Out:
# ['C:\\Users\\daarr\\Desktop\\Ironhack\\Proyectos\\Final_project_MAD_Flights\\data\\flights\\flights_with_metars.json\\0.part',
#  'C:\\Users\\daarr\\Desktop\\Ironhack\\Proyectos\\Final_project_MAD_Flights\\data\\flights\\flights_with_metars.json\\1.part']

# %% [markdown]
# ## Se sigue el mismo proceso entre los DataFrames de vuelos y de información de tráfico aéreo.

# %%
# fl_dask['Date'] = dd.to_datetime(fl_dask['Date'])
# mad_dask['Date'] = dd.to_datetime(mad_dask['Date'])

# # Ordenar ambos DataFrames por la columna de fecha
# fl_dask = fl_dask.sort_values('Date')
# mad_dask = mad_dask.sort_values('Date')

# # Realizar el merge asof para encontrar el registro de tráfico más cercano en el tiempo
# fl_dask = dd.merge_asof(fl_dask, mad_dask, on='Date', direction='backward')

# %% [markdown]
# ## Se eliminan todas las columnas adiccionadas salvo la de los ids del metar y del tráfico aéreo.

# %%
reorder = ['Date_time','flight_id','Metar_id', 'cod_flight_IATA', 'cod_flight_ICAO', 'Date',
       'week_day', 'status', 'airliner', 'cod_airliner_IATA',
       'cod_airliner_ICAO', 'Scheduled_dep', 'depart_time', 'dep_situation',
       'dep_mins_of_delay', 'city', 'cod_airport_IATA', 'cod_airport_ICAO',
       'arrival', 'arr_situation', 'arr_mins_of_delay', 'duration', 'resta']
fl_dask = fl_dask[reorder]

# %%
fl_dask.head()
# Out:
#                  Date_time  flight_id  Metar_id cod_flight_IATA  \
# 497985 2023-10-31 23:59:00          1         1          IB6833
# 497984 2023-10-31 23:59:00          3         1          IB6011
# 497983 2023-10-31 23:59:00          2         1          IB6841
# 497982 2023-10-31 23:55:00          6         1          IB6827
# 497981 2023-10-31 23:55:00          4         1          IB6589
#
#        cod_flight_ICAO        Date week_day  status airliner  \
# 497985         IBE6833  2023-10-31  Tuesday  Landed   Iberia
# 497984         IBE6011  2023-10-31  Tuesday  Landed   Iberia
# 497983         IBE6841  2023-10-31  Tuesday  Landed   Iberia
# 497982         IBE6827  2023-10-31  Tuesday  Landed   Iberia
# 497981         IBE6589  2023-10-31  Tuesday  Landed   Iberia
#
#        cod_airliner_IATA cod_airliner_ICAO Scheduled_dep depart_time  \
# 497985                IB               IBE         23:59       00:34
# 497984                IB               IBE         23:59       00:24
# ...

# %%
fl_dask = fl_dask.sort_values('Date_time', ascending=False).reset_index(drop = True)

# %% [markdown]
# ## Se vuelven a cambiar los nombres de las columnas a como estaban originalmente.

# %%
fl_dask = fl_dask.rename(columns ={"Date_time": "departure_date_time","Metar_id": "metar_id", "Date": "day"})

# %%
fl_dask.head()
# Out:
#   departure_date_time  flight_id  metar_id cod_flight_IATA cod_flight_ICAO  \
# 0 2023-10-31 23:59:00          1         1          IB6833         IBE6833
# 1 2023-10-31 23:59:00          2         1          IB6841         IBE6841
# 2 2023-10-31 23:59:00          3         1          IB6011         IBE6011
# 3 2023-10-31 23:55:00          4         1          IB6589         IBE6589
# 4 2023-10-31 23:55:00          5         1          IB6409         IBE6409
#
#           day week_day  status airliner cod_airliner_IATA cod_airliner_ICAO  \
# 0  2023-10-31  Tuesday  Landed   Iberia                IB               IBE
# 1  2023-10-31  Tuesday  Landed   Iberia                IB               IBE
# 2  2023-10-31  Tuesday  Landed   Iberia                IB               IBE
# 3  2023-10-31  Tuesday  Landed   Iberia                IB               IBE
# 4  2023-10-31  Tuesday  Landed   Iberia                IB               IBE
#
# ...

# %%
fl2 = fl_dask.compute()

# %%
fl2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 922599 entries, 0 to 424612
# Data columns (total 23 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   departure_date_time  922599 non-null  datetime64[ns]
#  1   flight_id            922599 non-null  int64
#  2   metar_id             922599 non-null  int64
#  3   cod_flight_IATA      922599 non-null  object
#  4   cod_flight_ICAO      922599 non-null  object
#  5   day                  922599 non-null  object
#  6   week_day             922599 non-null  object
#  7   status               922599 non-null  object
#  8   airliner             922599 non-null  object
#  9   cod_airliner_IATA    922599 non-null  object
#  10  cod_airliner_ICAO    922599 non-null  object
#  11  Scheduled_dep        922599 non-null  object
#  12  depart_time          922599 non-null  object
#  13  dep_situation        922599 non-null  object
# ...

# %% [markdown]
# ## Se exporta el DataFrame en distintos formatos

# %%
fl2.to_csv("../data/flights/flights_with_metarid.csv", index = False)

# %%
fl2.to_parquet("../data/flights/flights_with_metarid.gz", compression='gzip', index = False)

# %%
fl2.to_json("../data/flights/flights_with_metarid.json")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 fl2.to_json("../data/flights/flights_with_metarid.json")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:2650, in NDFrame.to_json(self, path_or_buf, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines, compression, index, indent, storage_options)
#    2647 config.is_nonnegative_int(indent)
#    2648 indent = indent or 0
# -> 2650 return json.to_json(
#    2651     path_or_buf=path_or_buf,
#    2652     obj=self,
#    2653     orient=orient,
#    2654     date_format=date_format,
#    2655     double_precision=double_precision,
#    2656     force_ascii=force_ascii,
#    2657     date_unit=date_unit,
#    2658     default_handler=default_handler,
#    2659     lines=lines,
#    2660     compression=compression,
#    2661     index=index,
# ...
